# %%
#Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
#from config import g_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size =2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ahipara
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | sorland
# Processing Record 4 of Set 1 | pangnirtung
# Processing Record 5 of Set 1 | port-gentil
# Processing Record 6 of Set 1 | union
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | pevek
# Processing Record 9 of Set 1 | kleck
# City not found. Skipping...
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | hamilton
# Processing Record 13 of Set 1 | sirfa
# City not found. Skipping...
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | ponta delgada
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | tazovskiy
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | qaqortoq
# Processing Record 21 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 1 | port elizabeth
# Processing Record 23 of Set 1 | tura
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | bambous virieux
# Processing Record 26 of Set 1 | east london
# Processing Record 27 of Set 1 | tateyama
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | sechura
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | virginia beach
# Processing Record 33 of Set 1 | hambantota
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | hithadhoo
# Processing Record 36 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | savannah bight
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | ulladulla
# Processing Record 41 of Set 1 | kaeo
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | kansanshi
# Processing Record 44 of Set 1 | eirunepe
# Processing Record 45 of Set 1 | namatanai
# Processing Record 46 of Set 1 | ola
# Processing Record 47 of Set 1 | las vegas
# Processing Record 48 of Set 1 | cheremukhovo
# Processing Record 49 of Set 1 | jabiru
# City not found. Skipping...
# Processing Record 50 of Set 1 | andros town
# Processing Record 1 of Set 2 | liuzhou
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | ilheus
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | erenhot
# Processing Record 6 of Set 2 | sabzevar
# Processing Record 7 of Set 2 | saint-philippe
# Processing Record 8 of Set 2 | matay
# Processing Record 9 of Set 2 | castro
# Processing Record 10 of Set 2 | longyearbyen
# Processing Record 11 of Set 2 | port hedland
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | tacuarembo
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | alice springs
# Processing Record 16 of Set 2 | okhotsk
# Processing Record 17 of Set 2 | mar del plata
# Processing Record 18 of Set 2 | amudat
# Processing Record 19 of Set 2 | chuy
# Processing Record 20 of Set 2 | nouadhibou
# Processing Record 21 of Set 2 | bighapur
# Processing Record 22 of Set 2 | at-bashi
# Processing Record 23 of Set 2 | tsagan aman
# Processing Record 24 of Set 2 | tiarei
# Processing Record 25 of Set 2 | ponta do sol
# Processing Record 26 of Set 2 | la ronge
# Processing Record 27 of Set 2 | kaitangata
# Processing Record 28 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 2 | kesennuma
# City not found. Skipping...
# Processing Record 30 of Set 2 | namibe
# Processing Record 31 of Set 2 | lagoa
# Processing Record 32 of Set 2 | khatanga
# Processing Record 33 of Set 2 | constitucion
# Processing Record 34 of Set 2 | bucerias
# Processing Record 35 of Set 2 | ushuaia
# Processing Record 36 of Set 2 | faanui
# Processing Record 37 of Set 2 | zambezi
# Processing Record 38 of Set 2 | ancud
# Processing Record 39 of Set 2 | raudeberg
# Processing Record 40 of Set 2 | opuwo
# Processing Record 41 of Set 2 | nikolskoye
# Processing Record 42 of Set 2 | mahebourg
# Processing Record 43 of Set 2 | jamestown
# Processing Record 44 of Set 2 | yar-sale
# Processing Record 45 of Set 2 | arraial do cabo
# Processing Record 46 of Set 2 | aklavik
# Processing Record 47 of Set 2 | san miguel
# Processing Record 48 of Set 2 | airai
# Processing Record 49 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 2 | guerrero negro
# Processing Record 1 of Set 3 | alofi
# Processing Record 2 of Set 3 | sekoma
# Processing Record 3 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 3 | katsuura
# Processing Record 5 of Set 3 | adrar
# Processing Record 6 of Set 3 | touros
# Processing Record 7 of Set 3 | kaliningrad
# Processing Record 8 of Set 3 | butaritari
# Processing Record 9 of Set 3 | qasigiannguit
# Processing Record 10 of Set 3 | tasiilaq
# Processing Record 11 of Set 3 | bat khela
# Processing Record 12 of Set 3 | cabo san lucas
# Processing Record 13 of Set 3 | henties bay
# Processing Record 14 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 3 | port blair
# Processing Record 16 of Set 3 | tabou
# Processing Record 17 of Set 3 | bredasdorp
# Processing Record 18 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 3 | san policarpo
# Processing Record 20 of Set 3 | micheweni
# Processing Record 21 of Set 3 | richards bay
# Processing Record 22 of Set 3 | chapais
# Processing Record 23 of Set 3 | kuna
# Processing Record 24 of Set 3 | bafoulabe
# Processing Record 25 of Set 3 | saint-augustin
# Processing Record 26 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 27 of Set 3 | okmulgee
# Processing Record 28 of Set 3 | plettenberg bay
# Processing Record 29 of Set 3 | mackenzie
# Processing Record 30 of Set 3 | severo-kurilsk
# Processing Record 31 of Set 3 | maningrida
# Processing Record 32 of Set 3 | florianopolis
# Processing Record 33 of Set 3 | carnarvon
# Processing Record 34 of Set 3 | morant bay
# Processing Record 35 of Set 3 | kasongo-lunda
# Processing Record 36 of Set 3 | padang
# Processing Record 37 of Set 3 | lahij
# Processing Record 38 of Set 3 | zeya
# Processing Record 39 of Set 3 | dickinson
# Processing Record 40 of Set 3 | prince rupert
# Processing Record 41 of Set 3 | cervo
# Processing Record 42 of Set 3 | letterkenny
# Processing Record 43 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 44 of Set 3 | yellowknife
# Processing Record 45 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 3 | tadine
# Processing Record 47 of Set 3 | kabalo
# Processing Record 48 of Set 3 | te anau
# Processing Record 49 of Set 3 | marsa matruh
# Processing Record 50 of Set 3 | nelson bay
# Processing Record 1 of Set 4 | port keats
# Processing Record 2 of Set 4 | sonoita
# Processing Record 3 of Set 4 | mezen
# Processing Record 4 of Set 4 | emmett
# Processing Record 5 of Set 4 | grindavik
# Processing Record 6 of Set 4 | ternate
# Processing Record 7 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 4 | valleyview
# Processing Record 9 of Set 4 | ferrol
# Processing Record 10 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 11 of Set 4 | goundam
# Processing Record 12 of Set 4 | malakal
# Processing Record 13 of Set 4 | thompson
# Processing Record 14 of Set 4 | cayenne
# Processing Record 15 of Set 4 | pallipattu
# Processing Record 16 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 4 | pala
# Processing Record 18 of Set 4 | baykit
# Processing Record 19 of Set 4 | peterhead
# Processing Record 20 of Set 4 | komsomolskiy
# Processing Record 21 of Set 4 | leningradskiy
# Processing Record 22 of Set 4 | karatau
# Processing Record 23 of Set 4 | maniitsoq
# Processing Record 24 of Set 4 | clyde river
# Processing Record 25 of Set 4 | hilo
# Processing Record 26 of Set 4 | la troncal
# Processing Record 27 of Set 4 | puerto ayora
# Processing Record 28 of Set 4 | chanasma
# Processing Record 29 of Set 4 | saint anthony
# Processing Record 30 of Set 4 | adelaide
# Processing Record 31 of Set 4 | jishou
# Processing Record 32 of Set 4 | richard toll
# City not found. Skipping...
# Processing Record 33 of Set 4 | samarai
# Processing Record 34 of Set 4 | sahagun
# Processing Record 35 of Set 4 | omboue
# Processing Record 36 of Set 4 | kodiak
# Processing Record 37 of Set 4 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 38 of Set 4 | vanimo
# Processing Record 39 of Set 4 | san carlos de bariloche
# Processing Record 40 of Set 4 | norman wells
# Processing Record 41 of Set 4 | esperance
# Processing Record 42 of Set 4 | luwero
# Processing Record 43 of Set 4 | vao
# Processing Record 44 of Set 4 | talnakh
# Processing Record 45 of Set 4 | dwarka
# Processing Record 46 of Set 4 | vostok
# Processing Record 47 of Set 4 | kiama
# Processing Record 48 of Set 4 | luderitz
# Processing Record 49 of Set 4 | mount isa
# Processing Record 50 of Set 4 | teodoro sampaio
# Processing Record 1 of Set 5 | kon tum
# Processing Record 2 of Set 5 | lebu
# Processing Record 3 of Set 5 | tuktoyaktuk
# Processing Record 4 of Set 5 | atar
# Processing Record 5 of Set 5 | ribeira grande
# Processing Record 6 of Set 5 | rivadavia
# Processing Record 7 of Set 5 | hasaki
# Processing Record 8 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 5 | fairbanks
# Processing Record 10 of Set 5 | tyumentsevo
# Processing Record 11 of Set 5 | saskylakh
# Processing Record 12 of Set 5 | kurilsk
# Processing Record 13 of Set 5 | mantua
# Processing Record 14 of Set 5 | maloy
# Processing Record 15 of Set 5 | karratha
# Processing Record 16 of Set 5 | narsaq
# Processing Record 17 of Set 5 | dongsheng
# Processing Record 18 of Set 5 | porto novo
# Processing Record 19 of Set 5 | victoria
# Processing Record 20 of Set 5 | lavrentiya
# Processing Record 21 of Set 5 | coihaique
# Processing Record 22 of Set 5 | flores da cunha
# Processing Record 23 of Set 5 | boende
# Processing Record 24 of Set 5 | saint-leu
# Processing Record 25 of Set 5 | hulan
# Processing Record 26 of Set 5 | lorengau
# Processing Record 27 of Set 5 | ashland
# Processing Record 28 of Set 5 | ilulissat
# Processing Record 29 of Set 5 | caravelas
# Processing Record 30 of Set 5 | kiruna
# Processing Record 31 of Set 5 | ust-tsilma
# Processing Record 32 of Set 5 | oranjemund
# Processing Record 33 of Set 5 | bankura
# Processing Record 34 of Set 5 | nishihara
# Processing Record 35 of Set 5 | morro bay
# Processing Record 36 of Set 5 | aksha
# Processing Record 37 of Set 5 | sao filipe
# Processing Record 38 of Set 5 | pacific grove
# Processing Record 39 of Set 5 | tuatapere
# Processing Record 40 of Set 5 | faya
# Processing Record 41 of Set 5 | along
# Processing Record 42 of Set 5 | areosa
# Processing Record 43 of Set 5 | bababe
# City not found. Skipping...
# Processing Record 44 of Set 5 | kirakira
# Processing Record 45 of Set 5 | rio gallegos
# Processing Record 46 of Set 5 | russell
# Processing Record 47 of Set 5 | itarema
# Processing Record 48 of Set 5 | amapa
# Processing Record 49 of Set 5 | tessalit
# Processing Record 50 of Set 5 | bracebridge
# Processing Record 1 of Set 6 | kamenka
# Processing Record 2 of Set 6 | camabatela
# Processing Record 3 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 6 | tucuma
# Processing Record 5 of Set 6 | kingston
# Processing Record 6 of Set 6 | upernavik
# Processing Record 7 of Set 6 | pizarro
# Processing Record 8 of Set 6 | bathsheba
# Processing Record 9 of Set 6 | miri
# Processing Record 10 of Set 6 | naberera
# Processing Record 11 of Set 6 | edd
# Processing Record 12 of Set 6 | new norfolk
# Processing Record 13 of Set 6 | gat
# Processing Record 14 of Set 6 | poum
# Processing Record 15 of Set 6 | tharad
# Processing Record 16 of Set 6 | margate
# Processing Record 17 of Set 6 | umm lajj
# Processing Record 18 of Set 6 | vigrestad
# Processing Record 19 of Set 6 | iqaluit
# Processing Record 20 of Set 6 | bida
# Processing Record 21 of Set 6 | tilichiki
# Processing Record 22 of Set 6 | kamalia
# Processing Record 23 of Set 6 | saldanha
# Processing Record 24 of Set 6 | rafai
# Processing Record 25 of Set 6 | ewa beach
# Processing Record 26 of Set 6 | laguna
# Processing Record 27 of Set 6 | cross lanes
# Processing Record 28 of Set 6 | geraldton
# Processing Record 29 of Set 6 | ambanja
# Processing Record 30 of Set 6 | kysyl-syr
# Processing Record 31 of Set 6 | kayerkan
# Processing Record 32 of Set 6 | buraydah
# Processing Record 33 of Set 6 | port macquarie
# Processing Record 34 of Set 6 | chokurdakh
# Processing Record 35 of Set 6 | makakilo city
# Processing Record 36 of Set 6 | torbay
# Processing Record 37 of Set 6 | olga
# Processing Record 38 of Set 6 | luena
# Processing Record 39 of Set 6 | angol
# Processing Record 40 of Set 6 | inhambane
# Processing Record 41 of Set 6 | princeton
# Processing Record 42 of Set 6 | peniche
# Processing Record 43 of Set 6 | luau
# Processing Record 44 of Set 6 | egvekinot
# Processing Record 45 of Set 6 | labuhan
# Processing Record 46 of Set 6 | coquimbo
# Processing Record 47 of Set 6 | jinka
# Processing Record 48 of Set 6 | marystown
# Processing Record 49 of Set 6 | cumpas
# Processing Record 50 of Set 6 | sovetskaya
# Processing Record 1 of Set 7 | nemuro
# Processing Record 2 of Set 7 | ionia
# Processing Record 3 of Set 7 | miraflores
# Processing Record 4 of Set 7 | saint-georges
# Processing Record 5 of Set 7 | arroyo grande
# Processing Record 6 of Set 7 | provideniya
# Processing Record 7 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 7 | takoradi
# Processing Record 9 of Set 7 | loralai
# Processing Record 10 of Set 7 | billings
# Processing Record 11 of Set 7 | quelimane
# Processing Record 12 of Set 7 | puerto santander
# Processing Record 13 of Set 7 | merauke
# Processing Record 14 of Set 7 | salalah
# Processing Record 15 of Set 7 | mitsamiouli
# Processing Record 16 of Set 7 | rockhampton
# Processing Record 17 of Set 7 | tezu
# Processing Record 18 of Set 7 | kachug
# Processing Record 19 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 20 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 7 | kendari
# Processing Record 22 of Set 7 | bubaque
# Processing Record 23 of Set 7 | dhanera
# Processing Record 24 of Set 7 | kavieng
# Processing Record 25 of Set 7 | kieta
# Processing Record 26 of Set 7 | kurumkan
# Processing Record 27 of Set 7 | seymchan
# Processing Record 28 of Set 7 | luwuk
# Processing Record 29 of Set 7 | rawson
# Processing Record 30 of Set 7 | tavira
# Processing Record 31 of Set 7 | zhigansk
# Processing Record 32 of Set 7 | khasan
# Processing Record 33 of Set 7 | cukai
# Processing Record 34 of Set 7 | tres arroyos
# Processing Record 35 of Set 7 | lasa
# Processing Record 36 of Set 7 | catamarca
# Processing Record 37 of Set 7 | puerto carreno
# Processing Record 38 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 7 | toftir
# City not found. Skipping...
# Processing Record 40 of Set 7 | ribas do rio pardo
# Processing Record 41 of Set 7 | zainsk
# Processing Record 42 of Set 7 | ubala
# Processing Record 43 of Set 7 | inza
# Processing Record 44 of Set 7 | ordzhonikidze
# Processing Record 45 of Set 7 | nome
# Processing Record 46 of Set 7 | cherskiy
# Processing Record 47 of Set 7 | asau
# Processing Record 48 of Set 7 | honiara
# Processing Record 49 of Set 7 | fomboni
# Processing Record 50 of Set 7 | anadyr
# Processing Record 1 of Set 8 | jibert
# Processing Record 2 of Set 8 | podyuga
# Processing Record 3 of Set 8 | tiksi
# Processing Record 4 of Set 8 | ugoofaaru
# Processing Record 5 of Set 8 | vestmannaeyjar
# Processing Record 6 of Set 8 | hanko
# Processing Record 7 of Set 8 | hirara
# Processing Record 8 of Set 8 | auki
# Processing Record 9 of Set 8 | asosa
# Processing Record 10 of Set 8 | atbasar
# Processing Record 11 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 8 | inta
# Processing Record 13 of Set 8 | sibu
# Processing Record 14 of Set 8 | dalinghe
# City not found. Skipping...
# Processing Record 15 of Set 8 | college
# Processing Record 16 of Set 8 | nenjiang
# Processing Record 17 of Set 8 | bilma
# Processing Record 18 of Set 8 | high wycombe
# Processing Record 19 of Set 8 | sitka
# Processing Record 20 of Set 8 | port hardy
# Processing Record 21 of Set 8 | samarinda
# Processing Record 22 of Set 8 | benguela
# Processing Record 23 of Set 8 | tevaitoa
# Processing Record 24 of Set 8 | ust-maya
# Processing Record 25 of Set 8 | georgetown
# Processing Record 26 of Set 8 | mehamn
# Processing Record 27 of Set 8 | los llanos de aridane
# Processing Record 28 of Set 8 | alekseyevka
# Processing Record 29 of Set 8 | yumen
# Processing Record 30 of Set 8 | tocopilla
# Processing Record 31 of Set 8 | aswan
# Processing Record 32 of Set 8 | beringovskiy
# Processing Record 33 of Set 8 | alta floresta
# Processing Record 34 of Set 8 | nabire
# Processing Record 35 of Set 8 | aykhal
# Processing Record 36 of Set 8 | nuristan
# Processing Record 37 of Set 8 | carora
# Processing Record 38 of Set 8 | bandarbeyla
# Processing Record 39 of Set 8 | saint-pierre
# Processing Record 40 of Set 8 | palmer
# Processing Record 41 of Set 8 | rantauprapat
# Processing Record 42 of Set 8 | pisco
# Processing Record 43 of Set 8 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 44 of Set 8 | benemerito de las americas
# Processing Record 45 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 8 | chardara
# Processing Record 47 of Set 8 | blacklick estates
# Processing Record 48 of Set 8 | the valley
# Processing Record 49 of Set 8 | verkhoyansk
# Processing Record 50 of Set 8 | beloha
# Processing Record 1 of Set 9 | nouakchott
# Processing Record 2 of Set 9 | rio branco
# Processing Record 3 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 4 of Set 9 | voi
# Processing Record 5 of Set 9 | kualakapuas
# Processing Record 6 of Set 9 | arlit
# Processing Record 7 of Set 9 | rio bueno
# Processing Record 8 of Set 9 | avrille
# Processing Record 9 of Set 9 | anajatuba
# Processing Record 10 of Set 9 | cam ranh
# Processing Record 11 of Set 9 | vila franca do campo
# Processing Record 12 of Set 9 | charters towers
# Processing Record 13 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 14 of Set 9 | biak
# Processing Record 15 of Set 9 | byron bay
# Processing Record 16 of Set 9 | kunnamkulam
# Processing Record 17 of Set 9 | pag
# Processing Record 18 of Set 9 | lompoc
# Processing Record 19 of Set 9 | osorno
# Processing Record 20 of Set 9 | ouallam
# Processing Record 21 of Set 9 | kidal
# Processing Record 22 of Set 9 | boz
# Processing Record 23 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 24 of Set 9 | sakakah
# Processing Record 25 of Set 9 | bengkulu
# Processing Record 26 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 9 | kenai
# Processing Record 28 of Set 9 | sao sebastiao
# Processing Record 29 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 9 | conde
# Processing Record 31 of Set 9 | kimbe
# Processing Record 32 of Set 9 | reinosa
# Processing Record 33 of Set 9 | heinola
# Processing Record 34 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 35 of Set 9 | husavik
# Processing Record 36 of Set 9 | astoria
# Processing Record 37 of Set 9 | suntar
# Processing Record 38 of Set 9 | csengod
# Processing Record 39 of Set 9 | sultanpur
# Processing Record 40 of Set 9 | kirkuk
# Processing Record 41 of Set 9 | pemangkat
# Processing Record 42 of Set 9 | myitkyina
# Processing Record 43 of Set 9 | klaksvik
# Processing Record 44 of Set 9 | candido mendes
# Processing Record 45 of Set 9 | kholm
# Processing Record 46 of Set 9 | havre-saint-pierre
# Processing Record 47 of Set 9 | dudinka
# Processing Record 48 of Set 9 | jumla
# Processing Record 49 of Set 9 | gwadar
# Processing Record 50 of Set 9 | bangolo
# Processing Record 1 of Set 10 | kununurra
# Processing Record 2 of Set 10 | acapulco
# Processing Record 3 of Set 10 | sobolevo
# Processing Record 4 of Set 10 | comodoro rivadavia
# Processing Record 5 of Set 10 | rio grande
# Processing Record 6 of Set 10 | cairo
# Processing Record 7 of Set 10 | sahrak
# City not found. Skipping...
# Processing Record 8 of Set 10 | paoua
# Processing Record 9 of Set 10 | kailua
# Processing Record 10 of Set 10 | isangel
# Processing Record 11 of Set 10 | amor
# Processing Record 12 of Set 10 | caceres
# Processing Record 13 of Set 10 | north platte
# Processing Record 14 of Set 10 | suwannaphum
# Processing Record 15 of Set 10 | yarmouth
# Processing Record 16 of Set 10 | kijang
# Processing Record 17 of Set 10 | fereydun kenar
# Processing Record 18 of Set 10 | luanda
# Processing Record 19 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 20 of Set 10 | ust-nera
# Processing Record 21 of Set 10 | wamba
# Processing Record 22 of Set 10 | mosquera
# Processing Record 23 of Set 10 | balasheyka
# Processing Record 24 of Set 10 | yeppoon
# Processing Record 25 of Set 10 | shimoda
# Processing Record 26 of Set 10 | naze
# Processing Record 27 of Set 10 | zhoucheng
# Processing Record 28 of Set 10 | kingsport
# Processing Record 29 of Set 10 | broome
# Processing Record 30 of Set 10 | tommot
# Processing Record 31 of Set 10 | nosy varika
# Processing Record 32 of Set 10 | hofn
# Processing Record 33 of Set 10 | whitefish
# Processing Record 34 of Set 10 | vardo
# Processing Record 35 of Set 10 | harper
# Processing Record 36 of Set 10 | urgut
# Processing Record 37 of Set 10 | ndende
# Processing Record 38 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 10 | sao joao da barra
# Processing Record 40 of Set 10 | saravena
# Processing Record 41 of Set 10 | srednekolymsk
# Processing Record 42 of Set 10 | crab hill
# City not found. Skipping...
# Processing Record 43 of Set 10 | myanaung
# Processing Record 44 of Set 10 | wadi maliz
# Processing Record 45 of Set 10 | meulaboh
# Processing Record 46 of Set 10 | nguruka
# Processing Record 47 of Set 10 | nuuk
# Processing Record 48 of Set 10 | dharmadam
# Processing Record 49 of Set 10 | deputatskiy
# Processing Record 50 of Set 10 | barwaha
# City not found. Skipping...
# Processing Record 1 of Set 11 | yoichi
# Processing Record 2 of Set 11 | saint george
# Processing Record 3 of Set 11 | sept-iles
# Processing Record 4 of Set 11 | jalu
# Processing Record 5 of Set 11 | ruteng
# Processing Record 6 of Set 11 | nisia floresta
# Processing Record 7 of Set 11 | panaba
# Processing Record 8 of Set 11 | progreso
# Processing Record 9 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 11 | catio
# Processing Record 11 of Set 11 | esteli
# Processing Record 12 of Set 11 | cabedelo
# Processing Record 13 of Set 11 | yulara
# Processing Record 14 of Set 11 | kondinskoye
# Processing Record 15 of Set 11 | kastrakion
# Processing Record 16 of Set 11 | goya
# Processing Record 17 of Set 11 | jardim
# Processing Record 18 of Set 11 | hami
# Processing Record 19 of Set 11 | masallatah
# Processing Record 20 of Set 11 | liberal
# Processing Record 21 of Set 11 | fort stewart
# Processing Record 22 of Set 11 | alepe
# Processing Record 23 of Set 11 | innisfail
# Processing Record 24 of Set 11 | san patricio
# Processing Record 25 of Set 11 | noshiro
# Processing Record 26 of Set 11 | bilibino
# Processing Record 27 of Set 11 | bilecik
# Processing Record 28 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 11 | rantoul
# Processing Record 30 of Set 11 | benalla
# Processing Record 31 of Set 11 | sturgeon falls
# Processing Record 32 of Set 11 | dayong
# Processing Record 33 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 11 | moa
# Processing Record 35 of Set 11 | sanmenxia
# Processing Record 36 of Set 11 | eyemouth
# Processing Record 37 of Set 11 | neryungri
# Processing Record 38 of Set 11 | cidreira
# Processing Record 39 of Set 11 | leshukonskoye
# Processing Record 40 of Set 11 | sakaiminato
# Processing Record 41 of Set 11 | johnstown
# Processing Record 42 of Set 11 | mount gambier
# Processing Record 43 of Set 11 | kongolo
# Processing Record 44 of Set 11 | kalabo
# Processing Record 45 of Set 11 | amahai
# Processing Record 46 of Set 11 | dingle
# Processing Record 47 of Set 11 | teguise
# Processing Record 48 of Set 11 | port-cartier
# Processing Record 49 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 11 | ventersburg
# Processing Record 1 of Set 12 | chimbote
# Processing Record 2 of Set 12 | kyabe
# Processing Record 3 of Set 12 | lima
# Processing Record 4 of Set 12 | gabu
# Processing Record 5 of Set 12 | beira
# Processing Record 6 of Set 12 | kilindoni
# Processing Record 7 of Set 12 | perth
# Processing Record 8 of Set 12 | waddan
# Processing Record 9 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 12 | labrea
# Processing Record 11 of Set 12 | rock springs
# Processing Record 12 of Set 12 | tecoanapa
# Processing Record 13 of Set 12 | thinadhoo
# Processing Record 14 of Set 12 | tari
# Processing Record 15 of Set 12 | kargil
# Processing Record 16 of Set 12 | burnie
# Processing Record 17 of Set 12 | santa cruz
# Processing Record 18 of Set 12 | neiafu
# Processing Record 19 of Set 12 | republic
# Processing Record 20 of Set 12 | black forest
# Processing Record 21 of Set 12 | gorom-gorom
# Processing Record 22 of Set 12 | manturovo
# Processing Record 23 of Set 12 | goderich
# Processing Record 24 of Set 12 | iranshahr
# Processing Record 25 of Set 12 | bandar-e anzali
# Processing Record 26 of Set 12 | muhos
# Processing Record 27 of Set 12 | basco
# Processing Record 28 of Set 12 | abu kamal
# Processing Record 29 of Set 12 | bugulma
# Processing Record 30 of Set 12 | maragogi
# Processing Record 31 of Set 12 | zalantun
# Processing Record 32 of Set 12 | shingu
# Processing Record 33 of Set 12 | providencia
# Processing Record 34 of Set 12 | hokitika
# Processing Record 35 of Set 12 | ozark
# Processing Record 36 of Set 12 | souillac
# Processing Record 37 of Set 12 | swabi
# Processing Record 38 of Set 12 | dolinsk
# Processing Record 39 of Set 12 | riohacha
# Processing Record 40 of Set 12 | half moon bay
# Processing Record 41 of Set 12 | hovd
# Processing Record 42 of Set 12 | athabasca
# Processing Record 43 of Set 12 | shenzhen
# Processing Record 44 of Set 12 | kahului
# Processing Record 45 of Set 12 | sola
# Processing Record 46 of Set 12 | kaohsiung
# Processing Record 47 of Set 12 | marrakesh
# Processing Record 48 of Set 12 | rivers
# Processing Record 49 of Set 12 | oktyabrskiy
# Processing Record 50 of Set 12 | najran
# Processing Record 1 of Set 13 | kodinsk
# Processing Record 2 of Set 13 | maykain
# City not found. Skipping...
# Processing Record 3 of Set 13 | elizabethtown
# Processing Record 4 of Set 13 | omsukchan
# Processing Record 5 of Set 13 | tutla
# City not found. Skipping...
# Processing Record 6 of Set 13 | codrington
# Processing Record 7 of Set 13 | muros
# Processing Record 8 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 9 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 10 of Set 13 | xichang
# Processing Record 11 of Set 13 | uhlove
# Processing Record 12 of Set 13 | puerto madryn
# Processing Record 13 of Set 13 | rafsanjan
# Processing Record 14 of Set 13 | cairns
# Processing Record 15 of Set 13 | miyako
# Processing Record 16 of Set 13 | killybegs
# Processing Record 17 of Set 13 | kavaratti
# Processing Record 18 of Set 13 | poronaysk
# Processing Record 19 of Set 13 | ballina
# Processing Record 20 of Set 13 | batagay-alyta
# Processing Record 21 of Set 13 | san jose
# Processing Record 22 of Set 13 | san cristobal acasaguastlan
# Processing Record 23 of Set 13 | shubarshi
# Processing Record 24 of Set 13 | ajdabiya
# Processing Record 25 of Set 13 | angoche
# Processing Record 26 of Set 13 | kruisfontein
# Processing Record 27 of Set 13 | rumonge
# Processing Record 28 of Set 13 | olafsvik
# Processing Record 29 of Set 13 | talara
# Processing Record 30 of Set 13 | wakkanai
# Processing Record 31 of Set 13 | garden city
# Processing Record 32 of Set 13 | paamiut
# Processing Record 33 of Set 13 | puerto escondido
# Processing Record 34 of Set 13 | kalispell
# Processing Record 35 of Set 13 | dunedin
# Processing Record 36 of Set 13 | berlevag
# Processing Record 37 of Set 13 | hit
# Processing Record 38 of Set 13 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 39 of Set 13 | praxedis guerrero
# Processing Record 40 of Set 13 | kohtla-jarve
# Processing Record 41 of Set 13 | muborak
# Processing Record 42 of Set 13 | talawdi
# City not found. Skipping...
# Processing Record 43 of Set 13 | sungaipenuh
# Processing Record 44 of Set 13 | banamba
# Processing Record 45 of Set 13 | bath
# Processing Record 46 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 13 | usinsk
# Processing Record 48 of Set 13 | maiduguri
# Processing Record 49 of Set 13 | palamos
# Processing Record 50 of Set 13 | coahuayana
# Processing Record 1 of Set 14 | tazmalt
# Processing Record 2 of Set 14 | waipawa
# Processing Record 3 of Set 14 | crotone
# Processing Record 4 of Set 14 | yertsevo
# Processing Record 5 of Set 14 | bontang
# Processing Record 6 of Set 14 | zhangjiakou
# Processing Record 7 of Set 14 | sandwick
# Processing Record 8 of Set 14 | bani
# Processing Record 9 of Set 14 | abha
# Processing Record 10 of Set 14 | nong phai
# Processing Record 11 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 14 | magistralnyy
# Processing Record 13 of Set 14 | potenza
# Processing Record 14 of Set 14 | kloulklubed
# Processing Record 15 of Set 14 | shishou
# Processing Record 16 of Set 14 | challapata
# Processing Record 17 of Set 14 | gardendale
# Processing Record 18 of Set 14 | sinnamary
# Processing Record 19 of Set 14 | marabba
# Processing Record 20 of Set 14 | kerch
# Processing Record 21 of Set 14 | wielun
# Processing Record 22 of Set 14 | kotlas
# Processing Record 23 of Set 14 | san quintin
# Processing Record 24 of Set 14 | santa maria
# Processing Record 25 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 26 of Set 14 | fare
# Processing Record 27 of Set 14 | haines junction
# Processing Record 28 of Set 14 | baoqing
# Processing Record 29 of Set 14 | el alto
# Processing Record 30 of Set 14 | moron
# Processing Record 31 of Set 14 | buckeye
# Processing Record 32 of Set 14 | bay roberts
# Processing Record 33 of Set 14 | cobija
# Processing Record 34 of Set 14 | oranjestad
# Processing Record 35 of Set 14 | wenling
# Processing Record 36 of Set 14 | key west
# Processing Record 37 of Set 14 | san felipe
# Processing Record 38 of Set 14 | maceio
# Processing Record 39 of Set 14 | izazi
# Processing Record 40 of Set 14 | banda aceh
# Processing Record 41 of Set 14 | nam tha
# City not found. Skipping...
# Processing Record 42 of Set 14 | shakiso
# Processing Record 43 of Set 14 | sao felix do xingu
# Processing Record 44 of Set 14 | zhangye
# Processing Record 45 of Set 14 | whitehorse
# Processing Record 46 of Set 14 | guanica
# Processing Record 47 of Set 14 | esna
# Processing Record 48 of Set 14 | zhezkazgan
# Processing Record 49 of Set 14 | roma
# Processing Record 50 of Set 14 | gazalkent
# Processing Record 1 of Set 15 | ossora
# Processing Record 2 of Set 15 | brewster
# Processing Record 3 of Set 15 | taree
# Processing Record 4 of Set 15 | gorin
# Processing Record 5 of Set 15 | gamba
# Processing Record 6 of Set 15 | port augusta
# Processing Record 7 of Set 15 | tupik
# Processing Record 8 of Set 15 | namangan
# Processing Record 9 of Set 15 | taltal
# Processing Record 10 of Set 15 | pryozerne
# Processing Record 11 of Set 15 | belmonte
# Processing Record 12 of Set 15 | visselhovede
# Processing Record 13 of Set 15 | abnub
# Processing Record 14 of Set 15 | ongandjera
# Processing Record 15 of Set 15 | san juan
# Processing Record 16 of Set 15 | ngunguru
# Processing Record 17 of Set 15 | porto walter
# Processing Record 18 of Set 15 | pangody
# Processing Record 19 of Set 15 | palana
# Processing Record 20 of Set 15 | polson
# Processing Record 21 of Set 15 | salobrena
# Processing Record 22 of Set 15 | rudnichnyy
# Processing Record 23 of Set 15 | sarangani
# Processing Record 24 of Set 15 | caboolture
# Processing Record 25 of Set 15 | santo antonio do ica
# Processing Record 26 of Set 15 | kaoma
# Processing Record 27 of Set 15 | camacha
# Processing Record 28 of Set 15 | ormara
# Processing Record 29 of Set 15 | tatvan
# Processing Record 30 of Set 15 | ngorongoro
# Processing Record 31 of Set 15 | el badari
# City not found. Skipping...
# Processing Record 32 of Set 15 | road town
# Processing Record 33 of Set 15 | mahanoro
# Processing Record 34 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 15 | manokwari
# Processing Record 36 of Set 15 | nha trang
# Processing Record 37 of Set 15 | maseru
# Processing Record 38 of Set 15 | makung
# City not found. Skipping...
# Processing Record 39 of Set 15 | lundazi
# Processing Record 40 of Set 15 | labytnangi
# Processing Record 41 of Set 15 | sabla
# Processing Record 42 of Set 15 | guajara-mirim
# City not found. Skipping...
# Processing Record 43 of Set 15 | estacion coahuila
# Processing Record 44 of Set 15 | kirensk
# Processing Record 45 of Set 15 | guozhen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 683

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Ahipara      NZ -35.1667  173.1667     58.06        74          96
# 1      Qaanaaq      GL  77.4840  -69.3632     43.23        67          17
# 2      Sorland      NO  67.6670   12.6934     51.66        89         100
# 3  Pangnirtung      CA  66.1451  -65.7125     50.94        68          64
# 4  Port-Gentil      GA  -0.7193    8.7815     75.16        83         100
# 5        Union      US  40.6334  -74.2663     82.29        50           0
# 6        Vaini      TO -21.2000 -175.2000     73.38        73         100
# 7        Pevek      RU  69.7008  170.3133     34.65        85          83
# 8       Avarua      CK -21.2078 -159.7750     75.25        60          40
# 9      Mataura      NZ -46.1927  168.8643     44.47        96         100
#
#    Wind Speed Current Description
# 0       13.24     overcast clouds
# 1        4.21          few clouds
# 2       29.84     overcast clouds
# 3        3.65       broken clouds
# 4       11.50     overcast clouds
# 5        8.05           clear sky
# 6       12.95     overcast clouds
# 7        8.97       broken clouds
# 8       17.27    scattered clouds
# 9        6.62     overcast clouds

# %%
city_data_df["Lat"] = city_data_df["Lat"].map("{:.2f}".format)
city_data_df["Lng"] = city_data_df["Lng"].map("{:.2f}".format)
city_data_df
# Out:
#                   City Country     Lat      Lng  Max Temp  Humidity  \
# 0              Ahipara      NZ  -35.17   173.17     58.06        74
# 1              Qaanaaq      GL   77.48   -69.36     43.23        67
# 2              Sorland      NO   67.67    12.69     51.66        89
# 3          Pangnirtung      CA   66.15   -65.71     50.94        68
# 4          Port-Gentil      GA   -0.72     8.78     75.16        83
# ..                 ...     ...     ...      ...       ...       ...
# 678         Labytnangi      RU   66.66    66.42     49.14        87
# 679              Sabla      NG   12.75     4.71     82.74        68
# 680  Estacion Coahuila      MX   32.19  -115.00    102.31        22
# 681            Kirensk      RU   57.79   108.11     58.39        84
# 682            Guozhen      CN   34.37   107.36     73.24        91
#
#      Cloudiness  Wind Speed Current Description
# 0            96       13.24     overcast clouds
# 1            17        4.21          few clouds
# 2           100       29.84     overcast clouds
# 3            64        3.65       broken clouds
# 4           100       11.50     overcast clouds
# ..          ...         ...                 ...
# 678         100       11.23     overcast clouds
# 679         100       14.70     overcast clouds
# 680          11       12.86          few clouds
# 681          94        4.12     overcast clouds
# 682         100        4.88     overcast clouds
#
# [683 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df.notnull().sum()
# Out:
# City                   683
# Country                683
# Lat                    683
# Lng                    683
# Max Temp               683
# Humidity               683
# Cloudiness             683
# Wind Speed             683
# Current Description    683
# dtype: int64
